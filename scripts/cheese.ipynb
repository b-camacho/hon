# %% [markdown]
# fetching from wikidata first

# %%
import requests
from typing import List, Dict
import time

def fetch_cheeses() -> List[Dict]:
    """
    Queries Wikidata for all types of cheese using SPARQL.
    Returns a list of dictionaries containing cheese information.
    """
    endpoint_url = "https://query.wikidata.org/sparql"
    
    # SPARQL query to get cheese items with their labels and descriptions
    query = """
    SELECT DISTINCT ?cheese ?cheeseLabel ?cheeseDescription ?countryLabel
    WHERE {
      # ?cheese wdt:P31/wdt:P279* wd:Q10943 .  # Instance of cheese or subclass of cheese
      
      OPTIONAL { ?cheese wdt:P495 ?country }  # Country of origin if available
      
      SERVICE wikibase:label { 
        bd:serviceParam wikibase:language "en" .
        # ?cheese rdfs:label ?cheeseLabel .
        # ?cheese schema:description ?cheeseDescription .
        # ?country rdfs:label ?countryLabel .
      }
    }
    """
    
    headers = {
        'User-Agent': 'CheeseCatalog/1.0 (https://github.com/yourusername; youremail@example.com)'
    }
    
    try:
        response = requests.get(
            endpoint_url,
            params={'query': query, 'format': 'json'},
            headers=headers
        )
        response.raise_for_status()
        
        results = response.json()['results']['bindings']
        
        cheeses = []
        for result in results:
            cheese_info = {
                'name': result['cheeseLabel']['value'],
                'description': result.get('cheeseDescription', {}).get('value', 'No description available'),
                'country': result.get('countryLabel', {}).get('value', 'Unknown origin'),
                'wikidata_id': result['cheese']['value'].split('/')[-1]
            }
            cheeses.append(cheese_info)
            
        return cheeses
        
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return []

# Fetch the cheeses
all_cheeses = fetch_cheeses()

# Print some sample results
print(f"Found {len(all_cheeses)} different types of cheese!")
for cheese in all_cheeses[:5]:  # Show first 5 cheeses
    print(f"\nName: {cheese['name']}")
    print(f"Description: {cheese['description']}")
    print(f"Country: {cheese['country']}")
    print(f"Wikidata ID: {cheese['wikidata_id']}")
# Out:
# /Users/bmc/sources/sph/scripts/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Found 232 different types of cheese!
#
# Name: Brânză de vaci
# Description: Romanian cheese
# Country: Moldova
# Wikidata ID: Q108112946
#
# Name: testun
# Description: cheese from Piedmont
# Country: Italy
# Wikidata ID: Q97172601
#
# Name: Camoscio d'oro
# Description: No description available
# Country: Unknown origin
# Wikidata ID: Q79087543
#
# Name: Chubut cheese
# Description: No description available
# Country: Unknown origin
# Wikidata ID: Q6094556
#
# Name: Tronchon
# Description: type of soft cheese from Spain
# Country: Spain
# Wikidata ID: Q6094605

# %% [markdown]
# changed my mind these are just from cheese.com

# %%
import json
cheese_json = None
with open('../data/cheeses.json') as f:
    cheese_json = json.load(f)

# %%
cheese_json
# Out:
# [{'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/Old_Gouda_-_48_Month.webp',
#   'name': 'Gouda'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/Briefermier.webp',
#   'name': 'Brie'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/10-American-Cheese-shutterstock_1610208106.webp',
#   'name': 'American Cheese'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Pecorino_romano_cheese.webp',
#   'name': 'Pecorino Romano'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/cheddar_large.webp',
#   'name': 'Cheddar'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/manchego_1280x800_1.webp',
#   'name': 'Manchego'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/170306-DS-Premium-Cheese-Smoked_381x242_acf_cropped.webp',
#   'name': 'Smoked Gouda'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/CamembertStLoup_800x.webp',
#   'name': 'Camembert'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Provolone.webp',
#   'name': 'Provolone'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/baby_bell_istock.webp',
#   'name': 'Babybel'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/parmesan_on_wooden_surface.webp',
#   'name': 'Parmesan'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/mascarpone_istock.webp',
#   'name': 'Mascarpone'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/mozzarella_cheese_on_wooden_cutting_board.webp',
#   'name': 'Mozzarella'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Formaggio_Asiago_Dop_mdAjQor-min.webp',
#   'name': 'Asiago DOP'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/feta_cheese_on_cutting_board.webp',
#   'name': 'Feta'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/20month_600x.webp',
#   'name': 'Le Gruyère AOP'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Gorgonzola_niUHULx.webp',
#   'name': 'Gorgonzola'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Grated-Monterey-Jack.webp',
#   'name': 'Monterey Jack'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/Stilton_Range_Shot.webp',
#   'name': 'Stilton'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Abbaye-de-Belloc.webp',
#   'name': 'Abbaye de Belloc'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/Taleggio-DOP_1280x800.webp',
#   'name': 'Taleggio'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Grana-Padano.webp',
#   'name': 'Grana Padano'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/wiki/swiss.webp',
#   'name': 'Swiss Cheese'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Boursin_cheese.webp',
#   'name': 'Boursin'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/08-cotija-shutterstock_171554048.webp',
#   'name': 'Cotija Cheese'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/IMG_3905.webp',
#   'name': "Fontina Val d'Aosta"},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/Roquefort-AOC_1280x800.webp',
#   'name': 'Roquefort'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Bleu_Cheese.webp',
#   'name': 'Blue Cheese'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/Emmental_6174830f-d536-4b99-964e-ea52f1ed6a57_800x.webp',
#   'name': 'Emmental'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Jarlsberg_in_Wholefoods_2.webp',
#   'name': 'Jarlsberg'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Mozzarella_di_Bufala.webp',
#   'name': 'Mozzarella di Bufala DOP'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/paper_jack.webp',
#   'name': 'Pepper Jack'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/Munster_1280x800.webp',
#   'name': 'Munster'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Bocconcini_cheese_by_LMa.webp',
#   'name': 'Bocconcini'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/14-FROMAGE-FRAIS-shutterstock_318526556.webp',
#   'name': 'Fromage Frais'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Ricotta_Salata.webp',
#   'name': 'Ricotta Salata'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Havarathi.webp',
#   'name': 'Cream Havarti'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Scamorza.webp',
#   'name': 'Scamorza'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/raclette-cheese.webp',
#   'name': 'Fromage a Raclette'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Goats_cheese.webp',
#   'name': 'Chèvre'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/pecorino_1280x800.webp',
#   'name': 'Pecorino'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/Burrata.webp',
#   'name': 'Burrata'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Halloumi.webp',
#   'name': 'Halloumi'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/WhatsAppImage2022-08-15at12.01.18PM_1.webp',
#   'name': 'Aged Gouda'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Fresh_Mozzarella.webp',
#   'name': 'Fresh Mozzarella'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/wiki/colby.webp',
#   'name': 'Colby'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Limburger-Kase.webp',
#   'name': 'Limburger kass'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/529_paneer.webp',
#   'name': 'Paneer'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/wiki/queso-blanco.webp',
#   'name': 'Queso Blanco'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Port_Salut.webp',
#   'name': 'Port-Salut'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Adelost_QnxYLx6.webp',
#   'name': 'Adelost'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/20220903_102054whiter.webp',
#   'name': 'Abondance'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/DeutschButterkase.webp',
#   'name': 'Butterkase'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/Brillat.webp',
#   'name': 'Brillat-Savarin'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/ComteFortStAntoine_straight_CC2209_9314_90313d2a-064e-4f46-9d81-59_qcDEp.webp',
#   'name': 'Comte'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/camembert-de-normandie-cheese.webp',
#   'name': 'Camembert de Normandie'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/reblochon_1280x800.webp',
#   'name': 'Reblochon AOC'},
#  {'href': 'https://www.cheese.com/static/common/img/icon-cheese-default.e8052fdfc02e.svg',
#   'name': 'Longhorn'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Queso_Oaxaca_bacUSwE.webp',
#   'name': 'Oaxaca'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Mont_des_Cats_kaas.webp',
#   'name': 'Abbaye du Mont des Cats'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/saint-agur-2.webp',
#   'name': 'Saint Agur'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/514_cottage_cheese.webp',
#   'name': 'Cottage Cheese'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/02-panela-shutterstock_1318681619.webp',
#   'name': 'Panela'},
#  {'href': 'https://www.cheese.com/static/common/img/icon-cheese-default.e8052fdfc02e.svg',
#   'name': 'Acapella'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/526_fresh_truffles.webp',
#   'name': 'Truffle Cheese'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Romano_3_Months_700512336.webp',
#   'name': 'Romano'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/Wensleydale_1280x800.webp',
#   'name': 'Wensleydale'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/double-gloucester-cheese.webp',
#   'name': 'Double Gloucester'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/rutland-red-cheese.webp',
#   'name': 'Red Leicester'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Abbaye-de-citeaux.webp',
#   'name': 'Abbaye de Citeaux'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/colby_jack_cubes_istock.webp',
#   'name': 'Colby-Jack'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Caciocavallo.webp',
#   'name': 'Caciocavallo'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Crottin_de_Chavignol.webp',
#   'name': 'Crottin de Chavignol'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/cream_cheese_bagel.webp',
#   'name': 'Cream Cheese'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Parmigiano_reggiano_piece_1.webp',
#   'name': 'Zanetti Parmigiano Reggiano'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Leipajuusto_cheese_with_cloudberry_jam.webp',
#   'name': 'Juustoleipa'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/1100-baby_swiss.webp',
#   'name': 'Baby Swiss'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/Brie_De_Meaux.webp',
#   'name': 'Brie de Meaux'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/Berkswell_1280x800.webp',
#   'name': 'Berkswell'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/fresh-ricotta.webp',
#   'name': 'Ricotta'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/Maasdam.webp',
#   'name': 'Maasdam'},
#  {'href': 'https://www.cheese.com/static/common/img/icon-cheese-default.e8052fdfc02e.svg',
#   'name': 'Canadian Cheddar'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Formedambert2_1280x800.webp',
#   'name': "Fourme d'Ambert AOC"},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Tomme.webp',
#   'name': 'Tomme'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/cantal.webp',
#   'name': 'Cantal'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Menonita_cheese.webp',
#   'name': 'Menonita'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Crescenza.webp',
#   'name': 'Crescenza-Stracchino'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/15-Queso-Iberico-shutterstock_1363195139.webp',
#   'name': 'Queso Iberico'},
#  {'href': 'https://www.cheese.com/static/common/img/icon-cheese-default.e8052fdfc02e.svg',
#   'name': 'Crema Mexicana'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Sage_derby_cheese.webp',
#   'name': 'Sage Derby'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Geitost.webp',
#   'name': 'Geitost'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/wiki/brick.webp',
#   'name': 'Brick'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/01-kasseri-shutterstock_130035044.webp',
#   'name': 'Kasseri'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/604-bel_paese.webp',
#   'name': 'Bel Paese'},
#  {'href': 'https://www.cheese.com/static/common/img/icon-cheese-default.e8052fdfc02e.svg',
#   'name': 'Affidelice au Chablis'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/-suggestion/pave-daffinois-cheese.webp',
#   'name': "Pave d'Affinois"},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Munster_X4wVKgi.webp',
#   'name': 'Muenster'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Danablu-Danish-Blue.webp',
#   'name': 'Danablu (Danish Blue)'},
#  {'href': 'https://www.cheese.com/static/common/img/icon-cheese-default.e8052fdfc02e.svg',
#   'name': 'Acorn'},
#  {'href': 'https://www.cheese.com/media/img/cheese-thumbs/Afuega_l_pitu.webp',
#   'name': "Afuega'l Pitu"}]

# %%
import json
import psycopg2
from psycopg2.extras import execute_values


db_config = {
    'dbname': 'hon',
    'user': 'hon',
    'password': 't6tsMFzdqDNbAPpiEEDt',
    'host': 'chmod.site',
    'port': '5432',
}

def seed_db(data):
    insert_query = """
        INSERT INTO images (name, href) 
        VALUES %s;
    """
    # prepare data for insertion
    values = [(item['name'], item['href']) for item in data]

    try:
        # connect to db
        with psycopg2.connect(**db_config) as conn:
            with conn.cursor() as cur:
                # execute batch insert
                execute_values(cur, insert_query, values)
                print(f"Seeded {len(values)} rows into the database.")
    except Exception as e:
        print(f"Error seeding database: {e}")

# call the function
seed_db(cheese_json)
# Out:
# Seeded 100 rows into the database.
